# %%
from statsmodels.graphics.mosaicplot import mosaic
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import xlrd
import openpyxl

# %%
gender = ['male','male','male','female','female','male']
pet=['cat','dog','dog','cat','dog','cat']
data=pd.DataFrame({'gender':gender,'pet':pet})
mosaic(data,['pet','gender'],title='Mosaic Plot',gap=.005,axes_label=True)
plt.show()

# %%
ebc = pd.read_csv("C:\\Users\\Dell\\Desktop\\DataEBC1.csv")
ebc
# Out:
#      On 1-10 scale, how clean would you be? Question1: Gender  \
# 0                                       7.0            Female
# 1                                       5.0              Male
# 2                                       6.0              Male
# 3                                       7.0            Female
# 4                                       5.0              Male
# 5                                       7.0              Male
# 6                                       5.0            Female
# 7                                       6.0              Male
# 8                                       6.0              Male
# 9                                      10.0              Male
# 10                                      5.0              Male
# 11                                      5.0            Female
# 12                                     10.0              Male
# 13                                      9.0              Male
# 14                                      6.0            Female
# 15                                      7.0              Male
# 16                                      8.0              Male
# 17                                      6.0              Male
# 18                                      6.0              Male
# 19                                      5.0              Male
# 20                                      9.0              Male
# 21                                      7.0              Male
# 22                                      6.0              Male
# 23                                     10.0              Male
# 24                                      8.0            Female
# 25                                      6.0              Male
# 26                                      7.0              Male
# 27                                     10.0              Male
# 28                                      5.0            Female
# 29                                      6.0              Male
# ..                                      ...               ...
# 220                                     NaN              Male
# 221                                     NaN            Female
# 222                                     NaN              Male
# 223                                     NaN              Male
# 224                                     NaN            Female
# 225                                     NaN            Female
# 226                                     NaN            Female
# 227                                     NaN            Female
# 228                                     NaN              Male
# 229                                     NaN            Female
# 230                                     NaN            Female
# 231                                     NaN            Female
# 232                                     NaN              Male
# 233                                     NaN              Male
# 234                                     NaN            Female
# 235                                     NaN            Female
# 236                                     NaN            Female
# 237                                     NaN              Male
# 238                                     NaN              Male
# 239                                     NaN            Female
# 240                                     NaN              Male
# 241                                     NaN              Male
# 242                                     NaN            Female
# 243                                     NaN              Male
# 244                                     NaN            Female
# 245                                     NaN              Male
# 246                                     NaN              Male
# 247                                     NaN            Female
# 248                                     NaN            Female
# 249                                     NaN              Male
#
#     Question 2: How many times in a day do you wash hands?  \
# 0                                                  3-4
# 1                                                  1-2
# 2                                                  3-4
# 3                                                  3-4
# 4                                                  1-2
# 5                                                  3-4
# 6                                                  5-6
# 7                                                  1-2
# 8                                                  3-4
# 9                                                  3-4
# 10                                                 3-4
# 11                                                 3-4
# 12                                                 5-6
# 13                                                 5-6
# 14                                                 3-4
# 15                                                 3-4
# 16                                                 3-4
# 17                                                 3-4
# 18                                                 3-4
# 19                                                 1-2
# 20                                                 3-4
# 21                                                 3-4
# 22                                                 3-4
# 23                                                 5-6
# 24                                                 3-4
# 25                                                 3-4
# 26                                                 3-4
# 27                                                 5-6
# 28                                                 5-6
# 29                                                 3-4
# ..                                                 ...
# 220                                                5-6
# 221                                                5-6
# 222                                                5-6
# 223                                                3-4
# 224                                                5-6
# 225                                                3-4
# 226                                                1-2
# 227                                                1-2
# 228                                                5-6
# 229                                  More than 7 times
# 230                                  More than 7 times
# 231                                                1-2
# 232                                                5-6
# 233                                                3-4
# 234                                                5-6
# 235                                                3-4
# 236                                                1-2
# 237                                                3-4
# 238                                                5-6
# 239                                                5-6
# 240                                                3-4
# 241                                                5-6
# 242                                                1-2
# 243                                                1-2
# 244                                                1-2
# 245                                                5-6
# 246                                                3-4
# 247                                                3-4
# 248                                                1-2
# 249                                                5-6
#
#     Question 3: Do you wash hands before eating food?  \
# 0                                           Sometimes
# 1                                               Never
# 2                                          Frequently
# 3                                          Frequently
# 4                                              Always
# 5                                          Frequently
# 6                                           Sometimes
# 7                                           Sometimes
# 8                                          Frequently
# 9                                              Always
# 10                                         Frequently
# 11                                             Always
# 12                                         Frequently
# 13                                             Always
# 14                                         Frequently
# 15                                         Frequently
# 16                                             Always
# 17                                         Frequently
# 18                                          Sometimes
# 19                                          Sometimes
# 20                                             Always
# 21                                          Sometimes
# 22                                             Always
# 23                                             Always
# 24                                          Sometimes
# 25                                          Sometimes
# 26                                             Always
# 27                                             Always
# 28                                         Frequently
# 29                                          Sometimes
# ..                                                ...
# 220                                        Frequently
# 221                                         Sometimes
# 222                                            Always
# 223                                            Always
# 224                                        Frequently
# 225                                            Always
# 226                                            Always
# 227                                        Frequently
# 228                                        Frequently
# 229                                            Always
# 230                                            Always
# 231                                        Frequently
# 232                                            Always
# 233                                            Always
# 234                                        Frequently
# 235                                            Always
# 236                                            Always
# 237                                            Always
# 238                                        Frequently
# 239                                            Always
# 240                                            Always
# 241                                        Frequently
# 242                                        Frequently
# 243                                        Frequently
# 244                                        Frequently
# 245                                            Always
# 246                                            Always
# 247                                            Always
# 248                                            Always
# 249                                        Frequently
#
#     Question 4: Do you use soap to wash hands?  \
# 0                                    Sometimes
# 1                                          NaN
# 2                                   Frequently
# 3                                    Sometimes
# 4                                    Sometimes
# 5                                    Sometimes
# 6                                    Sometimes
# 7                                    Sometimes
# 8                                   Frequently
# 9                                       Always
# 10                                  Frequently
# 11                                  Frequently
# 12                                  Frequently
# 13                                      Always
# 14                                  Frequently
# 15                                  Frequently
# 16                                   Sometimes
# 17                                   Sometimes
# 18                                   Sometimes
# 19                                   Sometimes
# 20                                   Sometimes
# 21                                   Sometimes
# 22                                   Sometimes
# 23                                   Sometimes
# 24                                   Sometimes
# 25                                  Frequently
# 26                                       Never
# 27                                      Always
# 28                                   Sometimes
# 29                                  Frequently
# ..                                         ...
# 220                                      Never
# 221                                  Sometimes
# 222                                     Always
# 223                                     Always
# 224                                     Always
# 225                                      Never
# 226                                     Always
# 227                                      Never
# 228                                      Never
# 229                                     Always
# 230                                     Always
# 231                                      Never
# 232                                     Always
# 233                                     Always
# 234                                     Always
# 235                                      Never
# 236                                     Always
# 237                                 Frequently
# 238                                      Never
# 239                                     Always
# 240                                 Frequently
# 241                                      Never
# 242                                      Never
# 243                                      Never
# 244                                      Never
# 245                                     Always
# 246                                     Always
# 247                                      Never
# 248                                     Always
# 249                                      Never
#
#     Question 5: Do you wash hands after using the toilet?  \
# 0                                            Sometimes
# 1                                            Sometimes
# 2                                           Frequently
# 3                                            Sometimes
# 4                                               Always
# 5                                               Always
# 6                                               Always
# 7                                            Sometimes
# 8                                            Sometimes
# 9                                               Always
# 10                                          Frequently
# 11                                              Always
# 12                                          Frequently
# 13                                              Always
# 14                                          Frequently
# 15                                              Always
# 16                                              Always
# 17                                              Always
# 18                                              Always
# 19                                              Always
# 20                                              Always
# 21                                              Always
# 22                                              Always
# 23                                              Always
# 24                                              Always
# 25                                              Always
# 26                                              Always
# 27                                              Always
# 28                                              Always
# 29                                              Always
# ..                                                 ...
# 220                                         Frequently
# 221                                         Frequently
# 222                                             Always
# 223                                             Always
# 224                                             Always
# 225                                         Frequently
# 226                                             Always
# 227                                         Frequently
# 228                                         Frequently
# 229                                             Always
# 230                                             Always
# 231                                         Frequently
# 232                                             Always
# 233                                             Always
# 234                                             Always
# 235                                         Frequently
# 236                                             Always
# 237                                         Frequently
# 238                                         Frequently
# 239                                             Always
# 240                                         Frequently
# 241                                         Frequently
# 242                                         Frequently
# 243                                         Frequently
# 244                                         Frequently
# 245                                             Always
# 246                                             Always
# 247                                         Frequently
# 248                                             Always
# 249                                         Frequently
#
#     Question 6: Do you wash hands as soon as you get home?  \
# 0                                                Never
# 1                                                Never
# 2                                            Sometimes
# 3                                            Sometimes
# 4                                            Sometimes
# 5                                            Sometimes
# 6                                            Sometimes
# 7                                            Sometimes
# 8                                            Sometimes
# 9                                               Always
# 10                                          Frequently
# 11                                          Frequently
# 12                                          Frequently
# 13                                              Always
# 14                                          Frequently
# 15                                          Frequently
# 16                                           Sometimes
# 17                                           Sometimes
# 18                                           Sometimes
# 19                                           Sometimes
# 20                                           Sometimes
# 21                                           Sometimes
# 22                                           Sometimes
# 23                                           Sometimes
# 24                                           Sometimes
# 25                                           Sometimes
# 26                                           Sometimes
# 27                                              Always
# 28                                          Frequently
# 29                                           Sometimes
# ..                                                 ...
# 220                                             Always
# 221                                         Frequently
# 222                                             Always
# 223                                             Always
# 224                                         Frequently
# 225                                         Frequently
# 226                                             Always
# 227                                              Never
# 228                                             Always
# 229                                             Always
# 230                                             Always
# 231                                              Never
# 232                                             Always
# 233                                             Always
# 234                                         Frequently
# 235                                         Frequently
# 236                                             Always
# 237                                             Always
# 238                                             Always
# 239                                         Frequently
# 240                                             Always
# 241                                             Always
# 242                                              Never
# 243                                              Never
# 244                                              Never
# 245                                             Always
# 246                                             Always
# 247                                         Frequently
# 248                                             Always
# 249                                             Always
#
#     Question 7: How do you wash hands?  \
# 0                                Water
# 1                         Soap - Water
# 2                                Water
# 3                         Soap - Water
# 4                                Water
# 5                                Water
# 6                                Water
# 7                                Water
# 8                                Water
# 9                         Soap - Water
# 10                               Water
# 11                               Water
# 12                               Water
# 13                               Water
# 14                               Water
# 15                               Water
# 16                               Water
# 17                               Water
# 18                               Water
# 19                               Water
# 20                               Water
# 21                               Water
# 22                               Water
# 23                               Water
# 24                               Water
# 25                               Water
# 26                               Water
# 27                               Water
# 28                               Water
# 29                               Water
# ..                                 ...
# 220                   Ash/sand - Water
# 221                       Soap - Water
# 222                       Soap - Water
# 223                       Soap - Water
# 224                       Soap - Water
# 225                              Water
# 226                       Soap - Water
# 227                              Water
# 228                   Ash/sand - Water
# 229                       Soap - Water
# 230                       Soap - Water
# 231                              Water
# 232                       Soap - Water
# 233                       Soap - Water
# 234                       Soap - Water
# 235                              Water
# 236                       Soap - Water
# 237                   Ash/sand - Water
# 238                   Ash/sand - Water
# 239                              Water
# 240                   Ash/sand - Water
# 241                   Ash/sand - Water
# 242                              Water
# 243                              Water
# 244                              Water
# 245                       Soap - Water
# 246                       Soap - Water
# 247                              Water
# 248                       Soap - Water
# 249                   Ash/sand - Water
#
#      Question 8: Is it important to wash hands?  \
# 0                                         Agree
# 1                                       Neutral
# 2                                         Agree
# 3                                         Agree
# 4                                         Agree
# 5                                         Agree
# 6                                         Agree
# 7                                         Agree
# 8                                       Neutral
# 9                                Strongly Agree
# 10                                        Agree
# 11                                        Agree
# 12                                        Agree
# 13                                        Agree
# 14                                      Neutral
# 15                                        Agree
# 16                                        Agree
# 17                                        Agree
# 18                                        Agree
# 19                                        Agree
# 20                                        Agree
# 21                                        Agree
# 22                                        Agree
# 23                               Strongly Agree
# 24                                      Neutral
# 25                                      Neutral
# 26                                        Agree
# 27                               Strongly Agree
# 28                                        Agree
# 29                               Strongly Agree
# ..                                          ...
# 220                              Strongly Agree
# 221                              Strongly Agree
# 222                                       Agree
# 223                              Strongly Agree
# 224                                       Agree
# 225                                       Agree
# 226                                       Agree
# 227                                    Disagree
# 228                              Strongly Agree
# 229                                       Agree
# 230                              Strongly Agree
# 231                                    Disagree
# 232                                       Agree
# 233                              Strongly Agree
# 234                                       Agree
# 235                                       Agree
# 236                                       Agree
# 237                                       Agree
# 238                              Strongly Agree
# 239                                       Agree
# 240                                       Agree
# 241                              Strongly Agree
# 242                                    Disagree
# 243                                    Disagree
# 244                                    Disagree
# 245                                       Agree
# 246                              Strongly Agree
# 247                                       Agree
# 248                                       Agree
# 249                              Strongly Agree
#
#     Question 9: You learnt hand washing etiquette's from?    ...  \
# 0                                               Elders       ...
# 1                                               Elders       ...
# 2                                              Parents       ...
# 3                                              Parents       ...
# 4                                              Parents       ...
# 5                                              Parents       ...
# 6                                              Parents       ...
# 7                                              Parents       ...
# 8                                               Elders       ...
# 9                                              Parents       ...
# 10                                              Elders       ...
# 11                                             Parents       ...
# 12                                             Parents       ...
# 13                                             Parents       ...
# 14                                              Elders       ...
# 15                                             Parents       ...
# 16                                              Elders       ...
# 17                                              Elders       ...
# 18                                             Parents       ...
# 19                                              Elders       ...
# 20                                              Elders       ...
# 21                                             Parents       ...
# 22                                             Parents       ...
# 23                                             Parents       ...
# 24                                             Parents       ...
# 25                                             Parents       ...
# 26                                             Parents       ...
# 27                                              Elders       ...
# 28                                              Elders       ...
# 29                                             Parents       ...
# ..                                                 ...       ...
# 220                                            Parents       ...
# 221                                           Teachers       ...
# 222                                            Parents       ...
# 223                                            Parents       ...
# 224                                            Parents       ...
# 225                                            Parents       ...
# 226                                             Elders       ...
# 227                                           Teachers       ...
# 228                                            Parents       ...
# 229                                            Parents       ...
# 230                                            Parents       ...
# 231                                           Teachers       ...
# 232                                            Parents       ...
# 233                                            Parents       ...
# 234                                            Parents       ...
# 235                                            Parents       ...
# 236                                             Elders       ...
# 237                                           Teachers       ...
# 238                                            Parents       ...
# 239                                             Elders       ...
# 240                                           Teachers       ...
# 241                                            Parents       ...
# 242                                           Teachers       ...
# 243                                           Teachers       ...
# 244                                           Teachers       ...
# 245                                            Parents       ...
# 246                                            Parents       ...
# 247                                            Parents       ...
# 248                                             Elders       ...
# 249                                            Parents       ...
#
#     Question 23: Do you think government should create awareness/plan on importance of hand wash?  \
# 0                                        Never Thought
# 1                                           Don't care
# 2                                        Never Thought
# 3                                                  Yes
# 4                                                  Yes
# 5                                                  Yes
# 6                                                   No
# 7                                        Never Thought
# 8                                        Never Thought
# 9                                                  Yes
# 10                                                 Yes
# 11                                                  No
# 12                                                 Yes
# 13                                       Never Thought
# 14                                                  No
# 15                                       Never Thought
# 16                                          Don't care
# 17                                       Never Thought
# 18                                       Never Thought
# 19                                       Never Thought
# 20                                       Never Thought
# 21                                       Never Thought
# 22                                                 Yes
# 23                                                 Yes
# 24                                       Never Thought
# 25                                          Don't care
# 26                                                  No
# 27                                                 Yes
# 28                                                  No
# 29                                                 Yes
# ..                                                 ...
# 220                                                Yes
# 221                                                 No
# 222                                                Yes
# 223                                                Yes
# 224                                                Yes
# 225                                      Never Thought
# 226                                                Yes
# 227                                      Never Thought
# 228                                                Yes
# 229                                                Yes
# 230                                                Yes
# 231                                      Never Thought
# 232                                                Yes
# 233                                                Yes
# 234                                                Yes
# 235                                      Never Thought
# 236                                                Yes
# 237                                      Never Thought
# 238                                                Yes
# 239                                                Yes
# 240                                      Never Thought
# 241                                                Yes
# 242                                      Never Thought
# 243                                      Never Thought
# 244                                      Never Thought
# 245                                                Yes
# 246                                                Yes
# 247                                      Never Thought
# 248                                                Yes
# 249                                                Yes
#
#     Question 24: Are you aware of the diseases that can occur if you don’t wash your hands?  \
# 0                                                   No
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                  Yes
# 5                                                  NaN
# 6                                                   No
# 7                                                   No
# 8                                                   No
# 9                                                  Yes
# 10                                       Never Thought
# 11                                       Never Thought
# 12                                                  No
# 13                                                  No
# 14                                                  No
# 15                                                 Yes
# 16                                                  No
# 17                                                  No
# 18                                                  No
# 19                                                  No
# 20                                                  No
# 21                                                 Yes
# 22                                                  No
# 23                                                 Yes
# 24                                       Never Thought
# 25                                                  No
# 26                                                  No
# 27                                                 Yes
# 28                                       Never Thought
# 29                                                 Yes
# ..                                                 ...
# 220                                                Yes
# 221                                                 No
# 222                                                 No
# 223                                      Never Thought
# 224                                                Yes
# 225                                      Never Thought
# 226                                                 No
# 227                                         Don't Care
# 228                                                Yes
# 229                                                Yes
# 230                                                 No
# 231                                         Don't Care
# 232                                                 No
# 233                                      Never Thought
# 234                                                Yes
# 235                                      Never Thought
# 236                                                 No
# 237                                                Yes
# 238                                                Yes
# 239                                      Never Thought
# 240                                                Yes
# 241                                                Yes
# 242                                         Don't Care
# 243                                         Don't Care
# 244                                         Don't Care
# 245                                                 No
# 246                                      Never Thought
# 247                                      Never Thought
# 248                                                 No
# 249                                                Yes
#
#     Question 25: Do you know any government schemes on importance of hand wash?  \
# 0                                                   No
# 1                                        Never Thought
# 2                                                  Yes
# 3                                           Don't Care
# 4                                                  Yes
# 5                                                   No
# 6                                                  Yes
# 7                                                   No
# 8                                                  Yes
# 9                                                  Yes
# 10                                                  No
# 11                                                 Yes
# 12                                                 Yes
# 13                                                 Yes
# 14                                                  No
# 15                                                 Yes
# 16                                                 Yes
# 17                                                 Yes
# 18                                                 Yes
# 19                                                  No
# 20                                                 Yes
# 21                                                 Yes
# 22                                                 Yes
# 23                                                 Yes
# 24                                                  No
# 25                                                 Yes
# 26                                                 Yes
# 27                                                 Yes
# 28                                                 Yes
# 29                                                 Yes
# ..                                                 ...
# 220                                      Never Thought
# 221                                      Never Thought
# 222                                      Never Thought
# 223                                                Yes
# 224                                      Never Thought
# 225                                      Never Thought
# 226                                                 No
# 227                                      Never Thought
# 228                                      Never Thought
# 229                                                 No
# 230                                                Yes
# 231                                      Never Thought
# 232                                      Never Thought
# 233                                                Yes
# 234                                      Never Thought
# 235                                      Never Thought
# 236                                                 No
# 237                                      Never Thought
# 238                                      Never Thought
# 239                                         Don't Care
# 240                                      Never Thought
# 241                                      Never Thought
# 242                                      Never Thought
# 243                                      Never Thought
# 244                                      Never Thought
# 245                                      Never Thought
# 246                                                Yes
# 247                                      Never Thought
# 248                                                 No
# 249                                      Never Thought
#
#       l Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31  \
# 0   NaN         NaN         NaN         NaN         NaN         NaN
# 1   NaN         NaN         NaN         NaN         NaN         NaN
# 2   NaN         NaN         NaN         NaN         NaN         NaN
# 3   NaN         NaN         NaN         NaN         NaN         NaN
# 4   NaN         NaN         NaN         NaN         NaN         NaN
# 5   NaN         NaN         NaN         NaN         NaN         NaN
# 6   NaN         NaN         NaN         NaN         NaN         NaN
# 7   NaN         NaN         NaN         NaN         NaN         NaN
# 8   NaN         NaN         NaN         NaN         NaN         NaN
# 9   NaN         NaN         NaN         NaN         NaN         NaN
# 10  NaN         NaN         NaN         NaN         NaN         NaN
# 11  NaN         NaN         NaN         NaN         NaN         NaN
# 12  NaN         NaN         NaN         NaN         NaN         NaN
# 13  NaN         NaN         NaN         NaN         NaN         NaN
# 14  NaN         NaN         NaN         NaN         NaN         NaN
# 15  NaN         NaN         NaN         NaN         NaN         NaN
# 16  NaN         NaN         NaN         NaN         NaN         NaN
# 17  NaN         NaN         NaN         NaN         NaN         NaN
# 18  NaN         NaN         NaN         NaN         NaN         NaN
# 19  NaN         NaN         NaN         NaN         NaN         NaN
# 20  NaN         NaN         NaN         NaN         NaN         NaN
# 21  NaN         NaN         NaN         NaN         NaN         NaN
# 22  NaN         NaN         NaN         NaN         NaN         NaN
# 23  NaN         NaN         NaN         NaN         NaN         NaN
# 24  NaN         NaN         NaN         NaN         NaN         NaN
# 25  NaN         NaN         NaN         NaN         NaN         NaN
# 26  NaN         NaN         NaN         NaN         NaN         NaN
# 27  NaN         NaN         NaN         NaN         NaN         NaN
# 28  NaN         NaN         NaN         NaN         NaN         NaN
# 29  NaN         NaN         NaN         NaN         NaN         NaN
# ..   ..         ...         ...         ...         ...         ...
# 220 NaN         NaN         NaN         NaN         NaN         NaN
# 221 NaN         NaN         NaN         NaN         NaN         NaN
# 222 NaN         NaN         NaN         NaN         NaN         NaN
# 223 NaN         NaN         NaN         NaN         NaN         NaN
# 224 NaN         NaN         NaN         NaN         NaN         NaN
# 225 NaN         NaN         NaN         NaN         NaN         NaN
# 226 NaN         NaN         NaN         NaN         NaN         NaN
# 227 NaN         NaN         NaN         NaN         NaN         NaN
# 228 NaN         NaN         NaN         NaN         NaN         NaN
# 229 NaN         NaN         NaN         NaN         NaN         NaN
# 230 NaN         NaN         NaN         NaN         NaN         NaN
# 231 NaN         NaN         NaN         NaN         NaN         NaN
# 232 NaN         NaN         NaN         NaN         NaN         NaN
# 233 NaN         NaN         NaN         NaN         NaN         NaN
# 234 NaN         NaN         NaN         NaN         NaN         NaN
# 235 NaN         NaN         NaN         NaN         NaN         NaN
# 236 NaN         NaN         NaN         NaN         NaN         NaN
# 237 NaN         NaN         NaN         NaN         NaN         NaN
# 238 NaN         NaN         NaN         NaN         NaN         NaN
# 239 NaN         NaN         NaN         NaN         NaN         NaN
# 240 NaN         NaN         NaN         NaN         NaN         NaN
# 241 NaN         NaN         NaN         NaN         NaN         NaN
# 242 NaN         NaN         NaN         NaN         NaN         NaN
# 243 NaN         NaN         NaN         NaN         NaN         NaN
# 244 NaN         NaN         NaN         NaN         NaN         NaN
# 245 NaN         NaN         NaN         NaN         NaN         NaN
# 246 NaN         NaN         NaN         NaN         NaN         NaN
# 247 NaN         NaN         NaN         NaN         NaN         NaN
# 248 NaN         NaN         NaN         NaN         NaN         NaN
# 249 NaN         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 32
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# ..          ...
# 220         NaN
# 221         NaN
# 222         NaN
# 223         NaN
# 224         NaN
# 225         NaN
# 226         NaN
# 227         NaN
# 228         NaN
# 229         NaN
# 230         NaN
# 231         NaN
# 232         NaN
# 233         NaN
# 234         NaN
# 235         NaN
# 236         NaN
# 237         NaN
# 238         NaN
# 239         NaN
# 240         NaN
# 241         NaN
# 242         NaN
# 243         NaN
# 244         NaN
# 245         NaN
# 246         NaN
# 247         NaN
# 248         NaN
# 249         NaN
#
# [250 rows x 33 columns]

# %%
tips = sns.load_dataset('tips')
print(tips)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# E:\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# E:\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# E:\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# E:\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# E:\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# E:\Anaconda3\lib\http\client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# E:\Anaconda3\lib\http\client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# E:\Anaconda3\lib\http\client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# E:\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     706     err = None
# --> 707     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     708         af, socktype, proto, canonname, sa = res
#
# E:\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-48-54237cd35b68> in <module>
# ----> 1 tips = sns.load_dataset('tips')
#       2 print(tips)
#
# E:\Anaconda3\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     426                                   os.path.basename(full_path))
#     427         if not os.path.exists(cache_path):
# --> 428             urlretrieve(full_path, cache_path)
#     429         full_path = cache_path
#     430
#
# E:\Anaconda3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# E:\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# E:\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# E:\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# E:\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# E:\Anaconda3\lib\urllib\request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# E:\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#    1321         except:
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>
